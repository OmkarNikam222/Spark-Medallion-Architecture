# %%
# %pip install -e ..

# %%
dbutils.fs.rm(
    "/Volumes/spark_demo/retail/bronze/bigmart",
    recurse=True
)

# %%
dbutils.fs.rm(
    "/Volumes/spark_demo/retail/silver/bigmart",
    recurse=True
)

# %%
from spark.jobs.run_bronze import main

main()
