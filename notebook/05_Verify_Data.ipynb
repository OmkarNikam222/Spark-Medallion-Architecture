# %%
bronze = spark.read.format("delta").load(
    "/Volumes/spark_demo/retail/bronze/bigmart"
)

display(bronze)

# %%
bronze.count()

# %%
silver = spark.read.format("delta").load(
    "/Volumes/spark_demo/retail/silver/bigmart"
)

display(silver)

# %%
silver.count()

# %%
silver.printSchema()

# %%
sales = spark.read.format("delta").load(
    "/Volumes/spark_demo/retail/gold/sales_summary"
)

display(sales)

# %%
outlet = spark.read.format("delta").load(
    "/Volumes/spark_demo/retail/gold/outlet_summary"
)

display(outlet)

# %%
category = spark.read.format("delta").load(
    "/Volumes/spark_demo/retail/gold/category_summary"
)

display(category)

# %%
item = spark.read.format("delta").load(
    "/Volumes/spark_demo/retail/gold/item_summary"
)

display(item)

# %%
kpi = spark.read.format("delta").load(
    "/Volumes/spark_demo/retail/gold/kpi_summary"
)

display(kpi)

# %%
# %sql
SHOW TABLES IN spark_demo.default
